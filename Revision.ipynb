# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, LabelEncoder, MinMaxScaler, MaxAbsScaler
from sklearn.linear_model import LinearRegression, Perceptron, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, confusion_matrix, classification_report, confusion_matrix
from sklearn.impute import SimpleImputer
from sklearn.utils import shuffle
import seaborn as sns
from sklearn.datasets import load_digits

# %% [markdown]
# #Linear

# %%
# !wget "https://archive.ics.uci.edu/ml/machine-learning-databases/communities/communities.data"
# Out:
# --2021-09-29 17:40:33--  https://archive.ics.uci.edu/ml/machine-learning-databases/communities/communities.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1102815 (1.1M) [application/x-httpd-php]
# Saving to: ‘communities.data.1’
#
# communities.data.1  100%[===================>]   1.05M  6.21MB/s    in 0.2s
#
# 2021-09-29 17:40:34 (6.21 MB/s) - ‘communities.data.1’ saved [1102815/1102815]

# %%
data = pd.read_csv('communities.data', header = None)

# %%
data.head()
# Out:
#    0   1      2                    3    4    ...  123  124   125   126   127
# 0    8   ?      ?         Lakewoodcity    1  ...  0.9  0.5  0.32  0.14  0.20
# 1   53   ?      ?          Tukwilacity    1  ...    ?    ?  0.00     ?  0.67
# 2   24   ?      ?         Aberdeentown    1  ...    ?    ?  0.00     ?  0.43
# 3   34   5  81440  Willingborotownship    1  ...    ?    ?  0.00     ?  0.12
# 4   42  95   6096    Bethlehemtownship    1  ...    ?    ?  0.00     ?  0.03
#
# [5 rows x 128 columns]

# %%
le = LabelEncoder()
data[3] = le.fit_transform(data[3])

# %%
imputer = SimpleImputer(missing_values = '?',strategy = 'most_frequent')
imputer = imputer.fit(data)
data = imputer.transform(data)

# %%
data
# Out:
# array([[8, '3', '1000', ..., 0.32, '0.14', 0.2],
#        [53, '3', '1000', ..., 0.0, '0.12', 0.67],
#        [24, '3', '1000', ..., 0.0, '0.12', 0.43],
#        ...,
#        [9, '9', '80070', ..., 0.91, '0.28', 0.23],
#        [25, '17', '72600', ..., 0.22, '0.18', 0.19],
#        [6, '3', '1000', ..., 1.0, '0.13', 0.48]], dtype=object)

# %%
data = pd.DataFrame(data)
data
# Out:
#      0   1      2     3   4     5    ...   122   123  124   125   126   127
# 0      8   3   1000   804   1  0.19  ...  0.04   0.9  0.5  0.32  0.14   0.2
# 1     53   3   1000  1625   1     0  ...  0.02  0.74    0     0  0.12  0.67
# 2     24   3   1000     1   1     0  ...  0.02  0.74    0     0  0.12  0.43
# 3     34   5  81440  1787   1  0.04  ...  0.02  0.74    0     0  0.12  0.12
# 4     42  95   6096   141   1  0.01  ...  0.02  0.74    0     0  0.12  0.03
# ...   ..  ..    ...   ...  ..   ...  ...   ...   ...  ...   ...   ...   ...
# 1989  12   3   1000  1597  10  0.01  ...  0.02  0.74    0     0  0.12  0.09
# 1990   6   3   1000  1455  10  0.05  ...  0.02  0.74    0     0  0.12  0.45
# 1991   9   9  80070  1707  10  0.16  ...  0.06  0.78    0  0.91  0.28  0.23
# 1992  25  17  72600  1695  10  0.08  ...  0.02  0.79    0  0.22  0.18  0.19
# 1993   6   3   1000  1165  10   0.2  ...  0.04  0.73  0.5     1  0.13  0.48
#
# [1994 rows x 128 columns]

# %%
data.columns
# Out:
# RangeIndex(start=0, stop=128, step=1)

# %%
df = pd.get_dummies(data = data, columns = [0,127])

# %%
df
# Out:
#        1      2     3   4     5  ... 127_0.94 127_0.95 127_0.96 127_0.97 127_1.0
# 0      3   1000   804   1  0.19  ...        0        0        0        0       0
# 1      3   1000  1625   1     0  ...        0        0        0        0       0
# 2      3   1000     1   1     0  ...        0        0        0        0       0
# 3      5  81440  1787   1  0.04  ...        0        0        0        0       0
# 4     95   6096   141   1  0.01  ...        0        0        0        0       0
# ...   ..    ...   ...  ..   ...  ...      ...      ...      ...      ...     ...
# 1989   3   1000  1597  10  0.01  ...        0        0        0        0       0
# 1990   3   1000  1455  10  0.05  ...        0        0        0        0       0
# 1991   9  80070  1707  10  0.16  ...        0        0        0        0       0
# 1992  17  72600  1695  10  0.08  ...        0        0        0        0       0
# 1993   3   1000  1165  10   0.2  ...        0        0        0        0       0
#
# ...

# %%
sc = StandardScaler()
sc.fit_transform(df)
df
# Out:
#        1      2     3   4     5  ... 127_0.94 127_0.95 127_0.96 127_0.97 127_1.0
# 0      3   1000   804   1  0.19  ...        0        0        0        0       0
# 1      3   1000  1625   1     0  ...        0        0        0        0       0
# 2      3   1000     1   1     0  ...        0        0        0        0       0
# 3      5  81440  1787   1  0.04  ...        0        0        0        0       0
# 4     95   6096   141   1  0.01  ...        0        0        0        0       0
# ...   ..    ...   ...  ..   ...  ...      ...      ...      ...      ...     ...
# 1989   3   1000  1597  10  0.01  ...        0        0        0        0       0
# 1990   3   1000  1455  10  0.05  ...        0        0        0        0       0
# 1991   9  80070  1707  10  0.16  ...        0        0        0        0       0
# 1992  17  72600  1695  10  0.08  ...        0        0        0        0       0
# 1993   3   1000  1165  10   0.2  ...        0        0        0        0       0
#
# ...

# %%
df = np.array(df[:])
X = df[:,:-1]
y = df[:,-1:]

# %%
X.shape
# Out:
# (1994, 269)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=2)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
print(mean_squared_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 0.001669449081802582
# 0.9316210045662273

# %%
#PolynomialFeatures
poly=PolynomialFeatures(degree=2)
X_train_poly=poly.fit_transform(X_train)
modelP=LinearRegression()
modelP.fit(X_train_poly,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_test_poly=poly.fit_transform(X_test)
y_predP=modelP.predict(X_test_poly)

# %%
mse = mean_squared_error(y_test,y_predP)
print(f"\nMSE: {mse}")

r2= r2_score(y_test,y_predP)
print(f"\nR2 Score (Linear Regression): {r2}")
# Out:
# MSE: 2.930482816896846
#
# R2 Score (Linear Regression): -119.02969922207826

# %% [markdown]
# #Playing with dataset

# %%
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/communities/communities.data', header = None)

# %%
data.describe()
# Out:
#                0            4    ...          125          127
# count  1994.000000  1994.000000  ...  1994.000000  1994.000000
# mean     28.683551     5.493982  ...     0.094052     0.237979
# std      16.397553     2.873694  ...     0.240328     0.232985
# min       1.000000     1.000000  ...     0.000000     0.000000
# 25%      12.000000     3.000000  ...     0.000000     0.070000
# 50%      34.000000     5.000000  ...     0.000000     0.150000
# 75%      42.000000     8.000000  ...     0.000000     0.330000
# max      56.000000    10.000000  ...     1.000000     1.000000
#
# [8 rows x 102 columns]

# %%
data.head()
# Out:
#    0   1      2                    3    4    ...  123  124   125   126   127
# 0    8   ?      ?         Lakewoodcity    1  ...  0.9  0.5  0.32  0.14  0.20
# 1   53   ?      ?          Tukwilacity    1  ...    ?    ?  0.00     ?  0.67
# 2   24   ?      ?         Aberdeentown    1  ...    ?    ?  0.00     ?  0.43
# 3   34   5  81440  Willingborotownship    1  ...    ?    ?  0.00     ?  0.12
# 4   42  95   6096    Bethlehemtownship    1  ...    ?    ?  0.00     ?  0.03
#
# [5 rows x 128 columns]

# %%
data.isnull().sum()
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 123    0
# 124    0
# 125    0
# 126    0
# 127    0
# Length: 128, dtype: int64

# %%
scaler = MinMaxScaler()
scaler.fit(df)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
ABS = MaxAbsScaler()
ABS.fit(df)
# Out:
# MaxAbsScaler(copy=True)

# %%
poly=PolynomialFeatures(degree=1)
X_train_poly=poly.fit_transform(X_train)
model2=LinearRegression()
model2.fit(X_train_poly,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_train.shape
# Out:
# (1395, 269)

# %%
y_train.shape
# Out:
# (1395, 1)

# %%
y_test.shape
# Out:
# (599, 1)

# %% [markdown]
# #Classification

# %%
data = pd.read_csv("https://raw.githubusercontent.com/ramahanisha-7/Datasets/main/claasify.csv")
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %%
data.describe()
# Out:
#               age         sex          cp  ...          ca        thal      target
# count  303.000000  303.000000  303.000000  ...  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  ...    0.729373    2.313531    0.544554
# std      9.082101    0.466011    1.032052  ...    1.022606    0.612277    0.498835
# min     29.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     47.500000    0.000000    0.000000  ...    0.000000    2.000000    0.000000
# 50%     55.000000    1.000000    1.000000  ...    0.000000    2.000000    1.000000
# 75%     61.000000    1.000000    2.000000  ...    1.000000    3.000000    1.000000
# max     77.000000    1.000000    3.000000  ...    4.000000    3.000000    1.000000
#
# [8 rows x 14 columns]

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df = np.array(data[:])

# %%
y = df[:,-1:]
X = df[:,:-1]

# %%
print(X.shape)
print(y.shape)
# Out:
# (303, 13)
# (303, 1)

# %%
X_train,X_test,y_train,y_test=train_test_split(data.drop(labels=['target'], axis=1),
    data['target'],
    test_size=0.3,
    random_state=0,
    shuffle=False)

# %%
clf = Perceptron(tol=1e-3, random_state=0)
clf.fit(X_train, y_train)
Perceptron()
z=clf.score(X_train, y_train)
print(f"\nThe accuracy using perceptron model is : {z}")
# Out:
# The accuracy using perceptron model is : 0.7735849056603774

# %%
model = LogisticRegression()

# %%
model = model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
y_pred = model.predict(X_test)

# %%
test_accuracy_sklearn = accuracy_score(y_test, y_pred)
test_accuracy_sklearn
# Out:
# 0.6153846153846154

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.62      0.76        91
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.62        91
#    macro avg       0.50      0.31      0.38        91
# weighted avg       1.00      0.62      0.76        91
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
conf_mat = confusion_matrix(y_test, y_pred)
conf_mat
# Out:
# array([[56, 35],
#        [ 0,  0]])
